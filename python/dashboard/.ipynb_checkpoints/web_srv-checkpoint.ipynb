# %%
from bottle import route, run, template,view

from bottle import static_file
@route('/')
@view("test")
def server_static():
    site1=[
        ['1005 Congress Avenue,Austin',0,10,'Austin','https://facebook.com'],
        ['10901 Baldwin Road,Baldwin',1,20,'Baldwin Energy Complex','https://youtube.com'],
        ['887 CR 257 Beckville',1,10,'Beckville Mine','https://youtube.com'],
        ['155 Maple Street,Bellingham',1,30,'Bellingham - ANP','https://youtube.com'],
        ['204 Elm Street,Blackstone',0,6,'Blackstone ANP','https://youtube.com'],
        ['11653 S Torrance Ave,Chicago',1,8,'Calumet','https://youtube.com'],
        ['125 Shore Road,Veazie',1,4,'Casco Bay Energy Facility','https://youtube.com'],
        ['105 East Fourth Street,Cincinnati',0,3,'Cincinnati Office (Clopays)','https://youtube.com'],
        ['312 Walnut Street,Cincinnati',1,4,'Cincinnati Office (Scripps Building)','http://evprappetsw01'],
        ['100 N Keechi St Fairfield',0,4,'Fairfield Real Estate Office','http://evprappetsw01'],
        ['134 CIPS Lane Coffeen',1,8,'Coffeen Power Station','http://evprappetsw01'],
        ['45 FM 2987 off Hwy 59 Fannin',1,6,'Coffeen Power Station','http://evprappetsw01'],
        ['1500 Eastport Plaza Dr.	Collinsville',1,4,'Collinsville Resource Center','http://evprappetsw01'],
        ['4950 Power Plant Court	Grandbury',1,4,'DeCordova - GPO','http://evprappetsw01'],
        ['632 TODHUNTER RD	MONROE',1,4,'DICKS CREEK GENERATING STATION','http://evprappetsw01'],
        ['17751 N. CILCO Rd.,	Canton',1,4,'Duck Creek Plant','http://evprappetsw01'],
        ['7800 CILCO Lane,	Bartonville',1,4,'Edwards Plant','http://evprappetsw01'],
        
    ]
    return dict(sites=site1)

run(host='localhost', port=7000, debug=True)
# Out:
# Bottle v0.12.13 server starting up (using WSGIRefServer())...
# Listening on http://localhost:7000/
# Hit Ctrl-C to quit.
#
# d:\python37\lib\site-packages\bottle.py:3468: DeprecationWarning: Flags not at the start of the expression "((?m)[urbURB]?(?:''(" (truncated)
#   patterns = [re.compile(p%pattern_vars) for p in patterns]
# d:\python37\lib\site-packages\bottle.py:3468: DeprecationWarning: Flags not at the start of the expression '\\{\\{((?:((?m)[urbURB' (truncated)
#   patterns = [re.compile(p%pattern_vars) for p in patterns]
# 127.0.0.1 - - [16/Aug/2018 21:52:43] "GET / HTTP/1.1" 200 3585
